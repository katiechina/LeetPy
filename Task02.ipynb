# %% [markdown]
# # Task 02：数组基础（2 天）

# %% [markdown]
# 第 02 天课程题目：
#
# ## [0066. 加一](https://leetcode-cn.com/problems/plus-one/)

# %%
def plusOne(digits):
    n = len(digits)
    for i in range(n-1, -1, -1):
        if digits[i] == 9:
            digits[i] = 0
        else:
            digits[i] += 1
            return digits
    return [1] + digits

# %%
plusOne([1,1])
# Out:
# [1, 2]

# %%
plusOne([9])
# Out:
# [1, 0]

# %% [markdown]
# ## [0724. 寻找数组的中心下标](https://leetcode-cn.com/problems/find-pivot-index/)

# %%
def pivotIndex(nums):
    for i in range(len(nums)):
        if sum(nums[:i]) == sum(nums[i+1:]):
            return i
    # if sum(nums[1:]) == 0:
    #     return 0
    # if sum(nums[:-1]) == 0:
    #     return len(nums)-1
    return -1

# %%
pivotIndex([1, 7, 3, 6, 5, 6])
# Out:
# 3

# %% [markdown]
# ## [0189. 旋转数组](https://leetcode-cn.com/problems/rotate-array/)

# %% [markdown]
# 输入: nums = [1,2,3,4,5,6,7], k = 3
# 输出: [5,6,7,1,2,3,4]
# 解释:
# 向右轮转 1 步: [7,1,2,3,4,5,6]
# 向右轮转 2 步: [6,7,1,2,3,4,5]
# 向右轮转 3 步: [5,6,7,1,2,3,4]

# %% [markdown]
# 方法一：一个一个翻转，执行起来比较慢，耗时太长，提交时显示超过时间限制
# 34 / 38 个通过测试用例

# %%
def rotate(nums, k):
    """
    Do not return anything, modify nums in-place instead.
    """
    n = len(nums)
    k = k%n
    for i in range(k):
        tmp = nums[-1]
        for i in range(n-1,-1,-1):
            nums[i] =nums[i-1]
        nums[0] = tmp

# %% [markdown]
# 方法二：看了评论区，大家普遍用切片的方法做的，这里使用python切片

# %%
def rotate(nums, k):
    """
    Do not return anything, modify nums in-place instead.
    """
    n = len(nums)
    nums[:] = nums[-k%n:] + nums[:-k%n]

# %% [markdown]
# 第 03 天课程题目：
#
# ## [0048. 旋转图像](https://leetcode-cn.com/problems/rotate-image/)

# %% [markdown]
# ![image.png](attachment:1571316b-c0fe-46f6-97af-dcb73b6a159c.png)

# %% [markdown]
# 当n是奇数时，如图，以12、36、89和47为一块，可以看成每一块沿着顺时针转了90度
# 当n是偶数时，就更简单了，可以划分成上下左右四块，然后沿着顺时针转了90度
# 一个元素matrix[i,j]旋转之后分别对应：
# i,j
# j,n-1-i
# n-1-i,n-1-j
# n-1-j,i
#
# 00
# 02
# 22
# 20
#
# 01
# 12
# 21
# 11

# %%
def rotate(matrix):
    """
    Do not return anything, modify matrix in-place instead.
    """
    n = len(matrix)
    x_range = 0
    y_range = 0
    if n%2 != 0:
        x_range = n//2
        y_range = n//2 + 1
    else:
        x_range = n//2
        y_range = n//2
    for i in range(x_range):
        for j in range(y_range):
            matrix[j][n-1-i],matrix[n-1-i][n-1-j],matrix[n-1-j][i],matrix[i][j]=matrix[i][j], matrix[j][n-1-i],matrix[n-1-i][n-1-j],matrix[n-1-j][i]

# %%
matrix = [[1,2,3],[4,5,6],[7,8,9]]
rotate(matrix)
matrix
# Out:
# [[7, 4, 1], [8, 5, 2], [9, 6, 3]]

# %% [markdown]
# ## [0054. 螺旋矩阵](https://leetcode-cn.com/problems/spiral-matrix/)

# %% [markdown]
# ![image.png](attachment:5a394485-d6d3-4448-9cf0-9f9873f3f381.png)

# %% [markdown]
# ## [0498. 对角线遍历](https://leetcode-cn.com/problems/diagonal-traverse/)

# %% [markdown]
# ![image.png](attachment:e7a3d989-ea5f-4c7b-937c-70a4fd6c40c6.png)
